# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
data = pd.read_csv('datafile.csv')

# %%
data.head()
# Out:
#                     Railway  \
# 0  Broad Gauge (1.676 m)(2)
# 1                   Central
# 2                   Eastern
# 3              East Central
# 4                East Coast
#
#    Number of passengers originating (1) (in Million) - 2009-10  \
# 0                                             7083.0
# 1                                             1556.0
# 2                                             1018.0
# 3                                              242.0
# 4                                               71.0
#
#    Number of passengers originating (1) (in Million) - 2010-11  \
# 0                                             7480.0
# 1                                             1629.0
# 2                                             1113.0
# 3                                              200.0
# 4                                               79.0
#
#    Earnings from passengers carried (in Million) - 2009-10  \
# 0                                           231408.0
# ...

# %%
data
# Out:
#                                   Railway  \
# 0                Broad Gauge (1.676 m)(2)
# 1                                 Central
# 2                                 Eastern
# 3                            East Central
# 4                              East Coast
# 5                                Northern
# 6                           North Central
# 7                           North Eastern
# 8                      Northeast Frontier
# 9                           North Western
# 10                               Southern
# 11                          South Central
# 12                          South Eastern
# 13                     South East Central
# 14                          South Western
# 15                                Western
# 16                           West Central
# 17               Metre Gauge (1.000 m)(2)
# 18                           East Central
# 19                          North Central
# 20                          North Eastern
# ...

# %%
data_broadgauge = data.iloc[1:17,:]
data_broadgauge
# Out:
#                Railway  \
# 1              Central
# 2              Eastern
# 3         East Central
# 4           East Coast
# 5             Northern
# 6        North Central
# 7        North Eastern
# 8   Northeast Frontier
# 9        North Western
# 10            Southern
# 11       South Central
# 12       South Eastern
# 13  South East Central
# 14       South Western
# 15             Western
# 16        West Central
#
#     Number of passengers originating (1) (in Million) - 2009-10  \
# 1                                              1556.0
# 2                                              1018.0
# 3                                               242.0
# 4                                                71.0
# 5                                               631.0
# 6                                               164.0
# 7                                               142.0
# 8                                                36.0
# ...

# %%
data_metregauge = data.iloc[18:27,:]
data_metregauge
# Out:
#                Railway  \
# 18        East Central
# 19       North Central
# 20       North Eastern
# 21  Northeast Frontier
# 22       North Western
# 23            Southern
# 24       South Central
# 25       South Western
# 26             Western
#
#     Number of passengers originating (1) (in Million) - 2009-10  \
# 18                                                7.0
# 19                                                NaN
# 20                                               86.0
# 21                                                9.0
# 22                                               11.0
# 23                                               21.0
# 24                                                2.0
# 25                                                NaN
# 26                                               26.0
#
#     Number of passengers originating (1) (in Million) - 2010-11  \
# 18                                                6.0
# ...

# %%
data_narrowgauge = data.iloc[28:36,:]
data_narrowgauge
# Out:
#                Railway  \
# 28             Central
# 29             Eastern
# 30          East Coast
# 31            Northern
# 32       North Central
# 33  Northeast Frontier
# 34       South Eastern
# 35  South East Central
#
#     Number of passengers originating (1) (in Million) - 2009-10  \
# 28                                                2.0
# 29                                                1.0
# 30                                                NaN
# 31                                                4.0
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                9.0
#
#     Number of passengers originating (1) (in Million) - 2010-11  \
# 28                                                1.0
# 29                                                NaN
# 30                                                NaN
# ...

# %%
data_broadgauge.columns
# Out:
# Index(['Railway',
#        'Number of passengers originating (1) (in Million) - 2009-10',
#        'Number of passengers originating (1) (in Million) - 2010-11',
#        'Earnings from passengers carried (in Million) - 2009-10',
#        'Earnings from passengers carried (in Million) - 2010-11',
#        'Load of goods (3) carried (1) (in Million Tonnes) - 2009-10',
#        'Load of goods (3) carried (1) (in Million Tonnes) - 2010-11',
#        'Earnings from goods carried (in Million) - 2009-10',
#        'Earnings from goods carried (in Million) - 2010-11'],
#       dtype='object')

# %%
plt.scatter(y="Railway",x="Number of passengers originating (1) (in Million) - 2009-10",data = data_broadgauge)

# %%
sns.barplot(y="Railway",x="Number of passengers originating (1) (in Million) - 2009-10",data =data_broadgauge,palette = "rainbow")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.barplot()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
plt.scatter(y="Railway",x="Number of passengers originating (1) (in Million) - 2010-11",data = data_broadgauge)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.barplot(y="Railway",x="Number of passengers originating (1) (in Million) - 2010-11",data =data_broadgauge,palette="rainbow")
